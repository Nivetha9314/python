# %%
num = int(input("Enter the number"))
if (num>0):
    print(" Entered number is positive number")
elif (num<0):
    print("Enterd number is negative number")
else:
    print("Entered number is Zero")
# Out:
# Enter the number 0
# Entered number is Zero

# %%
## two number is equal or not

num1 = int(input("Enter 1st number"))
num2 = int(input("Enter 2nd number"))

if (num1 == num2):
    print("Both numbers are equal")
else:
    print("Entered numbers are not equal")
# Out:
# Enter 1st number 20
# Enter 2nd number 20
# Both numbers are equal

# %%
## floating number is equal or not

num1 = float(input("Enter 1st number"))
num2 = float(input("Enter 2nd number"))

if (num1 == num2) and (num1-num2 <=0.0009):
    print("Both numbers are equal")
else:
    print("Entered numbers are not equal")
print(num1-num2)
# Out:
# Enter 1st number 20.3
# Enter 2nd number 20.3
# Both numbers are equal
# 0.0

# %%
## odd number or not

num = int(input("Enter a number"))
if(num%2 ==0):
    print("Entered number is even")
else:
    print("Entered number is odd")
# Out:
# Enter a number 5
# Entered number is odd

# %%
## leap year or not
year=int(input("Enter a year"))

if(year%4==0):
    print("Entered year is a leap year")
else:
    print("Entered year is not a leap year")
# Out:
# Enter a year 2004
# Entered year is a leap year

# %%
## eligible for vote 
age=int(input("Enter the age"))

if(age>=18) and (age<100):
    print("you are Eligible for voting")
elif(age<0) or (age>100):
    print("Enter a valid age")
else:
    print("you are not eligible for voting")
# Out:
# Enter the age 33
# you are Eligible for voting

# %%
## height prediction

height=float(input("Enter your height"))

if(height>=150) and (height<=200):
    print("you are tall")
elif(height>=100) and (height<150):
    print("you are medium height")
else:
    print("you are short")
# Out:
# Enter your height 90
# you are short

# %%
## largest amoung three numbers

a=int(input("Enter  a number"))
b=int(input("Enter  a number"))
c=int(input("Enter  a number"))

if a > b and a > c:
    print("a is largest")
elif b > a and b > c:
    print("b is largest")
else:
    print("c is largest")
# Out:
# Enter  a number 1
# Enter  a number 2
# Enter  a number 3
# c is largest

# %%
## smallest amoung three number


a=int(input("Enter  a number"))
b=int(input("Enter  a number"))
c=int(input("Enter  a number"))

if a < b and a < c:
    print("a is smallest")
elif b < a and b < c:
    print("b is smallest")
else:
    print("c is smallest")
# Out:
# Enter  a number 1
# Enter  a number 2
# Enter  a number 3
# a is smallest

# %%
##largest among four numbers

a=int(input("Enter  a number"))
b=int(input("Enter  a number"))
c=int(input("Enter  a number"))
d=int(input("Enter a number"))
temp=0
if (a > b):
    temp = a
else:
    temp = b
if(c>temp):
    temp=c
if(d>temp):
    temp=d
    print(temp)
# Out:
# Enter  a number 1
# Enter  a number 2
# Enter  a number 3
# Enter a number 4
# 4

# %%
## two numbers that are closer to each other.

a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))

ab = abs(a - b)
ac = abs(a - c)
bc = abs(b - c)

if ab <= ac and ab <= bc:
    print("a and b are closer")
elif ac <= ab and ac <= bc:
    print("a and c are closer")
else:
    print("b and c are closer")
# Out:
# Enter first number:  12
# Enter second number:  21
# Enter third number:  32
# a and b are closer

# %%
##the two numbers that are farther from each other

a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))

ab = abs(a - b)
ac = abs(a - c)
bc = abs(b - c)

if (ab >= ac) and (ab >= bc):
    print("a and b are farther")
elif (ac >= ab) and (ac >= bc):
    print("a and c are farther")
else:
    print("b and c are farther")
# Out:
# Enter first number:  100
# Enter second number:  1000
# Enter third number:  10000
# a and c are farther

# %%
##Sort three integers

a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))

if a <= b and b <= c:
    print(a, b, c)

elif a <= c and c <= b:
    print(a, c, b)

elif b <= a and a <= c:
    print(b, a, c)

elif b <= c and c <= a:
    print(b, c, a)

elif c <= a and a <= b:
    print(c, a, b)

else:
    print(c, b, a)
# Out:
# Enter first number:  1
# Enter second number:  2
# Enter third number:  3
# 1 2 3

# %%
## to check whether a triangle can be formed by the given value for the three angles.

a = float(input("Enter first angle: "))
b = float(input("Enter second angle: "))
c = float(input("Enter third angle: "))

if((a+b+c)==180):
    print("given angle can form triangle")
else:
    print("cannot form triangle")
# Out:
# Enter first angle:  20
# Enter second angle:  30
# Enter third angle:  130
# given angle can form triangle

# %%
##to accept a coordinate point in an XY coordinate system and determine in which quadrant
###the coordinate point lies

x=int(input("enter x value"))
y=int(input("enter y value"))

if(x>0 and y>0):
    print("xy lies in 1st quadrant")
elif(x>0 and y<0):
    print("xy lies in 4th quadrant")
elif(x<0 and y>0):
    print("xy lies in 2nd quarant")
elif(x<0 and y<0):
    print("xy lies in 3rd quadrant")
else:
    print("lies in same axis")
# Out:
# enter x value -4
# enter y value -2
# xy lies in 3rd quadrant

# %%
## if it is a vowel or a consonant.

x=input("enter a string")

if(x in ('a', 'e', 'i', 'o', 'u')):
    print("given letter is a vowel")
else:
    print("given letter is consonant")
# Out:
# enter a string l
# given letter is consonant

# %%
## the number of sides of a shape (3 sides up to 10 sides), return the name of that shape.

sides = int(input("Enter the number of sides: "))

if sides == 3:
    print("Triangle")
elif sides == 4:
    print("square")
elif sides == 5:
    print("Pentagon")
elif sides == 6:
    print("Hexagon")
elif sides == 8:
    print("Octagon")
else:
    print("Invalid input")
# Out:
# Enter the number of sides:  3
# Triangle

# %%
## Output number of days in a month given the month name. Assume 28 days in February.

month = input("Enter the month: ")

if month == "February":
    print("28 days")
elif month == "April" or month == "June" or month == "September" or month == "November":
    print("30 days")
elif month == "January" or month == "March" or month == "May" or month == "July" or month == "August" or month == "October" or month == "December":
    print("31 days")
else:
    print("Invalid month")
# Out:
# Enter the month:  January
# 31 days

# %%
##Print the day of week (Monday or Tuesday,...) given the day of month (1 to 31). Assume the month
##starts on a Monday.
day = int(input("Enter the day of the month (1-31): "))

if day % 7 == 1:
    print("Monday")
elif day % 7 == 2:
    print("Tuesday")
elif day % 7 == 3:
    print("Wednesday")
elif day % 7 == 4:
    print("Thursday")
elif day % 7 == 5:
    print("Friday")
elif day % 7 == 6:
    print("Saturday")
else:
    print("Sunday")
# Out:
# Enter the day of the month (1-31):  28
# Sunday

# %%
##Program to convert grade-points to letter grades. (A=>90, B =>80, C=>60, D=>50, F<50)

marks = int(input("Enter the marks: "))

if marks >= 90:
    print("Grade A")
elif marks >= 80:
    print("Grade B")
elif marks >= 60:
    print("Grade C")
elif marks >= 50:
    print("Grade D")
else:
    print("Grade F")
# Out:
# Enter the marks:  55
# Grade D

# %%
## Program to calculate profit or loss on a given transaction.

cp = float(input("Enter the cost price: "))
sp = float(input("Enter the selling price: "))

if sp > cp:
    print("Profit ", sp - cp)
elif sp < cp:
    print("Loss ", cp - sp)
else:
    print("No Profit No Loss")
# Out:
# Enter the cost price:  5000
# Enter the selling price:  1000
# Loss  4000.0

# %%
## Menu-Driven Program to perform a simple calculation of addition, subtraction, multiplication,
##division and modulo division.

a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

print("1. Addition")
print("2. Subtraction")
print("3. Multiplication")
print("4. Division")
print("5. Modulo Division")

choice = int(input("Enter your choice: "))

if choice == 1:
    print("Addition =", a + b)
elif choice == 2:
    print("Subtraction =", a - b)
elif choice == 3:
    print("Multiplication =", a * b)
elif choice == 4:
    print("Division =", a / b)
elif choice == 5:
    print("Modulo =", a % b)
else:
    print("Invalid choice")
# Out:
# Enter first number:  1
# Enter second number:  2
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Modulo Division
# Enter your choice:  1
# Addition = 3

# %%
##a program for Rock, Paper and Scissors Game. Just for a single round, Computer vs. User and
##declare the winner with proper reason.

import random
a=int(input("Enter a number"))

##print(random.randint(1,4))

comp = random.randint(1,3)
print(comp)
if(comp == 1 and a == 2):
    print("you win")
elif(comp == 2 and a == 3):
    print("you lose")
elif(comp ==3 and a == 1):
    print(" you win")
elif( comp ==1 and a ==3):
    print("you win")
elif( comp ==3 and a ==2):
    print("you lose")
else:
    print("match draw")
# Out:
# Enter a number 1
# 1
# match draw

# %%
##What colour is that square, given the row as int (1-8) and column as char (a-h) in a chess board.
##Given 5, ‘a’ the color is black. 3, ‘d’ the color is white.

row = int(input("Enter row (1-8): "))
col = int(input("Enter column (1-8): "))

if (row + col) % 2 == 0:
    print("Black")
else:
    print("White")
# Out:
# Enter row (1-8):  1
# Enter column (1-8):  1
# Black

# %%
## Read the lengths of sides of a triangle and name the triangle. (Equilateral, isosceles and scalene)

a = int(input("Enter first side: "))
b = int(input("Enter second side: "))
c = int(input("Enter third side: "))

if a == b == c:
    print("Equilateral Triangle")
elif a == b or b == c or a == c:
    print("Isosceles Triangle")
else:
    print("Scalene Triangle")
# Out:
# Enter first side:  20
# Enter second side:  20
# Enter third side:  20
# Equilateral Triangle
