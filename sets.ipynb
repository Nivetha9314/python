# %%
## creating a set
a={1}
type(a)
# Out:
# set

# %%
b= set()
type(b)
# Out:
# set

# %%
## list to set
l=[1,2,3]
s=set(l)
print(s)
# Out:
# {1, 2, 3}

# %%
## adding elements
s.add(10)
print(s)
# Out:
# {10, 1, 2, 3}

# %%
## removeing elements
s.remove(3)
print(s)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[37], line 2
#       1 ## removeing elements
# ----> 2 s.remove(3)
#       3 print(s)
#
# KeyError: 3

# %%
if 3 in s:
    s.remove(3)

# %%
print(s)
s.pop()
print(s)
# Out:
# {10, 1, 2}
# {1, 2}

# %%
s.clear()
print(s)
# Out:
# set()

# %%
new_set={1,2,3,4,5}
print(3 in new_set)
# Out:
# True

# %%
## mathematical operation
s1={1,2,3,4,5}
s2={4,5,6,7,8}

# %%
## union
s1.union(s2)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
s1.intersection(s2)
# Out:
# {4, 5}

# %%
s1.difference(s2)
# Out:
# {1, 2, 3}

# %%
##set methods
set1={1,2,3,4,5}
set2={2,3,4}
set2.issubset(set1)
# Out:
# True

# %%
set2.issuperset(set1)
# Out:
# False

# %%
text='hi this is python program this is easy to learn'

# %%
set(text.split())
# Out:
# {'easy', 'hi', 'is', 'learn', 'program', 'python', 'this', 'to'}

# %%
text1 =set()
for i in text.split():
    text1.add(i)
print(text1)
print(len(text1))
# Out:
# {'is', 'python', 'this', 'to', 'program', 'hi', 'learn', 'easy'}
# 8
